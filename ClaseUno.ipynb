# %% [markdown]
# ## Clase 1 - Introducción a Python

# %%
print('hola')
# Out:
# hola

# %% [markdown]
# ## Cargando las librerias

# %%
import numpy as np
x=50
y=np.random.rand(x)
y
# Out:
# array([0.21594344, 0.41758766, 0.55406444, 0.16412897, 0.47992643,
#        0.1586651 , 0.17663327, 0.7695127 , 0.64598424, 0.4906624 ,
#        0.18126766, 0.06734018, 0.47725633, 0.48693976, 0.34369848,
#        0.61878491, 0.91192198, 0.26252795, 0.64298859, 0.63704847,
#        0.28441243, 0.07633808, 0.05138747, 0.59676115, 0.24681975,
#        0.96327445, 0.15541897, 0.56827846, 0.41042609, 0.59947281,
#        0.73372512, 0.2989115 , 0.63866216, 0.91719547, 0.14333322,
#        0.28936864, 0.21424802, 0.73998848, 0.85478265, 0.72193517,
#        0.22771912, 0.98444083, 0.89295839, 0.65794824, 0.33295068,
#        0.08594264, 0.793729  , 0.80204608, 0.9837586 , 0.18880369])

# %% [markdown]
# ## Tipos de datos

# %%
import math
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
x='nombre1'
x
# Out:
# 'nombre1'

# %%
type(x)
# Out:
# str

# %%
numbers=[1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
numbers[3]
# Out:
# 4

# %%
sum_numbers=sum(numbers)
sum_numbers
# Out:
# 15

# %%
length=len(numbers)
length
# Out:
# 5

# %%
promedio=sum_numbers/length
promedio
# Out:
# 3.0

# %%
type(3/5)
# Out:
# float

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
numbers=[math.pi,3/5,4.0,'nombre',True]
numbers
# Out:
# [3.141592653589793, 0.6, 4.0, 'nombre', True]

# %%
type(True)
# Out:
# bool

# %%
type('True')
# Out:
# str

# %%
print(None)
# Out:
# None

# %%
type(None)
# Out:
# NoneType

# %%
type(None)
# Out:
# NoneType

# %%
x=16
y=8
if x < y:
    print('{} es menor que {}'. format(x,y))
else:
    print(x,' es mayor que ',y)
# Out:
# 16  es mayor que  8

# %%
unaLista=[True,6<5,1==3,None is None]
unaLista
# Out:
# [True, False, False, True]

# %% [markdown]
# ## El uso de for loop

# %%
for element in unaLista:
    print(element,'\t',type(element))
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %% [markdown]
# ## Lista

# %%
unaLista=['first','second','third','fourth','fifth','sixth']
unaLista
# Out:
# ['first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
#unaLista.sort()
#unaLista

# %%
unaLista[:1]
# Out:
# ['first']

# %%
unaLista[:]
# Out:
# ['first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
unaLista[1:3] #sin incluir elemento en la posición 3
# Out:
# ['second', 'third']

# %%
unaLista[5]
# Out:
# 'sixth'

# %%
unaLista[-1:]
# Out:
# ['sixth']

# %%
unaLista[-3:-1] #no incluye elemento en posición -1
# Out:
# ['fourth', 'fifth']

# %%
unaLista[-3:]
# Out:
# ['fourth', 'fifth', 'sixth']

# %% [markdown]
# #  SP: Tonelada métrica per cápita de emisiones de CO2
# Charbely Cisneros A01720514

# %% [markdown]
# ## Introducción

# %% [markdown]
# Este conjunto de datos fue generado por el centro Carbon Dioxide Information Analysis Center de Tennessee en los Estados Unidos y fue extraido de la página de The World Bank.
#
# Enlace a The World Bank para descargar: https://data.worldbank.org/indicator/EN.ATM.CO2E.PC?view=chart

# %% [markdown]
# ### Descripción de los datos

# %% [markdown]
# En este set de datos podemos encontrar las toneladas métricas de emisiones de CO2 (dioxido de carbono) de 236 países de los años 1960-2018.
#
# La tabla tiene las siguientes columnas:

# %%
df.columns
# Out:
# Index(['Country Code', 'Region', 'IncomeGroup', 'Indicator Name',
#        'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974',
#        '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        'Total'],
#       dtype='object')

# %% [markdown]
# De interes:
# * 'Country Name' es un variable cualitativa, explica los nombres de los países bajo estudio.
# * 'Country Code' es un variable cualitativa, explica el codigo de los países bajo estudio.
# * 'Region' es una variable cualitativa, explica la región donde pertenecen los países bajo estudio. Tiene como opciones: Europe & Central Asia, Latin America & Caribbean, Middle East & North Africa, North America, South Asia, Sub-Saharan Africa y East Asia & Pacific.
# * '1960' - '2018' es una variable cuantitativa, explica las cantidad de toneladas metricas de emisiones de CO2 por cada país bajo estudio en ese año.
# * 'Total' es una variable cuantitativa, contiene la suma de toneladas metricas de emisiones de CO2 de cada país en los años 1960-2018.
# * 'Income Group' es una variable cualitativa, explica el grupo de ingresos de los países bajo estudio. Tiene como opciones: High income, Low income, Lower middle income, Upper middle income

# %% [markdown]
# ### Tabla

# %%
df
# Out:
#                      Country Code                      Region  \
# Country Name
# Afghanistan                   AFG                  South Asia
# Angola                        AGO          Sub-Saharan Africa
# Albania                       ALB       Europe & Central Asia
# Andorra                       AND       Europe & Central Asia
# United Arab Emirates          ARE  Middle East & North Africa
# ...                           ...                         ...
# Samoa                         WSM         East Asia & Pacific
# Yemen, Rep.                   YEM  Middle East & North Africa
# South Africa                  ZAF          Sub-Saharan Africa
# Zambia                        ZMB          Sub-Saharan Africa
# Zimbabwe                      ZWE          Sub-Saharan Africa
#
#                               IncomeGroup  \
# Country Name
# Afghanistan                    Low income
# Angola                Lower middle income
# Albania               Upper middle income
# Andorra                       High income
# United Arab Emirates          High income
# ...                                   ...
# Samoa                 Lower middle income
# Yemen, Rep.                    Low income
# South Africa          Upper middle income
# Zambia                Lower middle income
# Zimbabwe              Lower middle income
#
#                                               Indicator Name  Indicator Code  \
# Country Name
# Afghanistan           CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# Angola                CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# Albania               CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# Andorra               CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# United Arab Emirates  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# ...                                                      ...             ...
# Samoa                 CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# Yemen, Rep.           CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# South Africa          CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# Zambia                CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# Zimbabwe              CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
#
#                           1960      1961      1962      1963      1964  ...  \
# Country Name                                                            ...
# Afghanistan           0.046057  0.053589  0.073721  0.074161  0.086174  ...
# Angola                0.100835  0.082204  0.210533  0.202739  0.213562  ...
# Albania               1.258195  1.374186  1.439956  1.181681  1.111742  ...
# Andorra                    NaN       NaN       NaN       NaN       NaN  ...
# United Arab Emirates  0.119037  0.109136  0.163542  0.175833  0.132815  ...
# ...                        ...       ...       ...       ...       ...  ...
# Samoa                 0.135031  0.163542  0.158377  0.184037  0.208106  ...
# Yemen, Rep.           0.011038  0.013599  0.012729  0.014518  0.017550  ...
# South Africa          5.727223  5.832621  5.887168  5.961337  6.332343  ...
# Zambia                     NaN       NaN       NaN       NaN  0.946606  ...
# Zimbabwe                   NaN       NaN       NaN       NaN  1.034904  ...
#
#                            2010       2011       2012       2013       2014  \
# Country Name
# Afghanistan            0.297065   0.407074   0.335351   0.263716   0.234037
# Angola                 1.221515   1.216317   1.204799   1.261542   1.285365
# Albania                1.572251   1.734823   1.579092   1.654524   1.806789
# Andorra                6.157198   5.850886   5.944654   5.942801   5.807128
# United Arab Emirates  19.043279  18.589933  19.223116  20.015421  19.951852
# ...                         ...        ...        ...        ...        ...
# Samoa                  1.021813   1.066843   1.057703   1.048702   1.092498
# Yemen, Rep.            1.036068   0.869051   0.804146   1.047834   1.034330
# South Africa           8.300179   7.867124   8.076633   8.137333   8.213158
# Zambia                 0.194032   0.218210   0.277909   0.284058   0.311693
# Zimbabwe               0.772579   0.891090   0.923360   0.925816   0.894256
#
#                            2015       2016       2017       2018        Total
# Country Name
# Afghanistan            0.232176   0.208857   0.203328   0.200151     8.813541
# Angola                 1.260921   1.227703   1.034317   0.887380    40.564875
# Albania                1.759987   1.714126   1.948872   1.939732    97.965540
# Andorra                6.026182   6.080600   6.104134   5.973405   196.566394
# United Arab Emirates  20.948092  21.307610  21.950614  20.797498  1794.578010
# ...                         ...        ...        ...        ...          ...
# Samoa                  1.240246   1.542099   1.535642   1.631588    40.887810
# Yemen, Rep.            0.536269   0.400468   0.361418   0.326682    26.085665
# South Africa           7.671202   7.564451   7.632729   7.496645   442.350573
# Zambia                 0.319282   0.341615   0.414748   0.446065    26.396457
# Zimbabwe               0.897598   0.783303   0.718570   0.849793    66.108364
#
# [188 rows x 65 columns]

# %% [markdown]
# ## Pregunta de Investigación 1: ¿Cuál es el comportamiento de México en sus emisiones de CO2?

# %%
dfmex=df.loc['Mexico',años]

dfmex.plot(kind='line',figsize=(20,7))

plt.xticks(fontsize=16,rotation=45)
plt.yticks(fontsize=16,rotation=45)

plt.title('Emisiones de CO2 en México', fontsize=20)

plt.xlabel('Años', fontsize=16)
plt.ylabel('Tonelada métrica de CO2', fontsize=16)
plt.text(50,4,'Acuerdo de Paris', fontsize=16)
plt.show()

# %% [markdown]
# ### Conclusión

# %% [markdown]
# * México ha incrementado sus emisiones de CO2 desde 1960.
# * Desde el Acuerdo de París, México ha tenido una tendencia negativa en sus emisiones de CO2.

# %% [markdown]
# ## Pregunta de Investigación 2: ¿Cuáles son los países que han emitido más CO2 durante los años?  ¿Cuáles son los que han emitido menos CO2?

# %%
df_topten=df.sort_values(by='Total', 
                          ascending=False,
                          axis=0,
                         )
df_topten=df_topten.head(10)
df_topten=df_topten.loc[:,'Total']

df_bottten=df.sort_values(by='Total', 
                          ascending=True,
                          axis=0,
                         )
df_bottten=df_bottten.head(10)
df_bottten=df_bottten.loc[:,'Total']

fig=plt.figure()

ax1=fig.add_subplot(1,2,1) #1 renglon, 2 columnas, posicion 1
df_topten.plot(kind='bar',figsize=(20,5))

plt.xticks(fontsize=12,rotation=45)
plt.yticks(fontsize=16,rotation=45)

plt.title('Países con más emisiones de CO2', fontsize=20)

plt.xlabel('País', fontsize=16)
plt.ylabel('Tonelada métrica de CO2', fontsize=16)   

ax2=fig.add_subplot(1,2,2) #1 renglon, 2 columnas, posicion 2
df_bottten.plot(kind='bar')
plt.xticks(fontsize=12,rotation=45)
plt.yticks(fontsize=16,rotation=45)

plt.title('Países con menos emisiones de CO2', fontsize=20)

plt.xlabel('País', fontsize=16)
plt.ylabel('Tonelada métrica de CO2', fontsize=16)
# Out:
# Text(0, 0.5, 'Tonelada métrica de CO2')

# %% [markdown]
# ### Conclusión

# %% [markdown]
# * Muchos de los que se encuentran en los mayores lugares son del Middle East y América del Norte.
# * Al igual, los que se enuentran en la gráfica de menores emisiones de CO2 son de Africa.

# %% [markdown]
# ## Pregunta de Investigación 3: ¿Qué regiones son las que más emiten CO2?

# %%
my_pivot=pd.pivot_table(df,
                        index='Region',
                        values='Total',
                       )
my_pivot.plot(kind='bar',figsize=(20,5))
plt.xticks(fontsize=16,rotation=45)
plt.yticks(fontsize=16,rotation=45)

plt.title('Emisiones de CO2 por región', fontsize=20)

plt.xlabel('Región', fontsize=16)
plt.ylabel('Tonelada métrica de CO2', fontsize=16)
# Out:
# Text(0, 0.5, 'Tonelada métrica de CO2')

# %% [markdown]
# ### Conclusión

# %% [markdown]
# * En esta gráfica podemos observar que las regiones con mayor emisiones de CO2 son "Middle East & North Africa" y "North America."
# * La región con menores emisiones de CO2 son de "South Asia" y "Sub-Saharan Africa."
# * ¿El estar en un tipo de región tiene un impacto en la cantidad de emisiones de CO2?

# %% [markdown]
# ## Pregunta de Investigación 4: ¿Hay alguna relación entre el tipo de región y sus emisiones de CO2?

# %%
modelA= sm.OLS.from_formula('Total~Region', data=df)
resultA= modelA.fit()
resultA.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Total   R-squared:                       0.258
# Model:                            OLS   Adj. R-squared:                  0.233
# Method:                 Least Squares   F-statistic:                     10.49
# Date:                Tue, 30 Nov 2021   Prob (F-statistic):           5.57e-10
# Time:                        22:48:23   Log-Likelihood:                -1337.0
# No. Observations:                 188   AIC:                             2688.
# Df Residuals:                     181   BIC:                             2711.
# Df Model:                           6
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                              224.5964     56.166      3.999      0.000     113.772     335.420
# Region[T.Europe & Central Asia]        102.9719     70.863      1.453      0.148     -36.853     242.796
# Region[T.Latin America & Caribbean]    -69.5717     76.986     -0.904      0.367    -221.477      82.333
# Region[T.Middle East & North Africa]   310.5905     87.913      3.533      0.001     137.123     484.058
# Region[T.North America]                793.7558    221.125      3.590      0.000     357.441    1230.070
# Region[T.South Asia]                  -197.1967    120.789     -1.633      0.104    -435.533      41.139
# Region[T.Sub-Saharan Africa]          -183.3518     71.422     -2.567      0.011    -324.278     -42.426
# ==============================================================================
# Omnibus:                      165.146   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2703.978
# Skew:                           3.280   Prob(JB):                         0.00
# Kurtosis:                      20.382   Cond. No.                         11.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Observaciones
# * Variable dependiente: 'Total'
# * Variable independiente: 'Region'
# * R-sq: 0.258; por lo tanto, este modelo no es tan bueno ya que solo explica en 25.8% de la variación basada en la variable 'Region'
# ...
# * Df model: 6
# * Intercept... < 0.05,  es estadisticamente sigificativa para el modelo
#
# ` Total = 224.5964 + 102.9719*R(Europe_CentralAsia) - 69.5717*R(LatinAmerica_Caribbean) + 310.5905*R(MiddleEast_NorthAfrica) + 793.7558*R(NorthAmerica) - 197.1967*R(SouthAsia) - 183.3518*R(Sub-SaharanAfrica) `
#
# ### Caso de estudio:
# DF Model: 6
# * R(Europe_CentralAsia) = False
# * R(LatinAmerica_Caribbean) = False
# * R(MiddleEast_NorthAfrica) = False
# * R(NorthAmerica) = True
# * R(SouthAsia) = False
# * R(Sub-SaharanAfrica) = False

# %%
print('Las emisiones total de CO2 de un país de Norte America es \t', 224.5964 + 102.9719*0 - 69.5717*0 + 310.5905*0 + 793.7558*1 - 197.1967*0 - 183.3518*0)

df.iloc[-11:-10,64:]
# Out:
# Las emisiones total de CO2 de un país de Norte America es 	 1018.3522
#                      Total
# Country Name
# United States  1112.701532

# %%
df.iloc[29:30,64:]
# Out:
#                    Total
# Country Name
# Canada        924.002982

# %% [markdown]
# ### Conclusión
# * El modelo no es confiable.
# * Puede haber muchos paises en una region, no significa que tendran las mismas emisiones de CO2, como vemos en el caso de Canda y Estados Unidos
# * Hay más variable que pudieran tener un impacto en las emisiones de CO2

# %% [markdown]
# ## Pregunta de Investigación 5: ¿Cuál es el income group que emite más CO2?

# %%
my_pivot2=pd.pivot_table(df,index='IncomeGroup', values='Total')

my_pivot2=my_pivot2.drop([0],axis=0)
my_pivot2=my_pivot2.reset_index()
my_pivot2=my_pivot2.rename({'index':'IncomeGroup'}, axis=1)

explode_list =[0.03,0.04,0.05,0.06]

my_pivot2['Total'].plot(kind='pie',
                        figsize=(10,15),
                        startangle=90,
                        labels=None,
                        autopct='%1.1f%%',
                        pctdistance=1.1,
                        explode=explode_list,
                        shadow=True,
                        textprops={'fontsize':18})

plt.legend(labels=my_pivot2.IncomeGroup,bbox_to_anchor=(1.0,0.9),title='Leyenda',title_fontsize=20)
plt.title('Piechart de Total de emisiones de CO2 por Income Group')
plt.show()

# %% [markdown]
# * De los paises que más emiten CO2, tienen un High Income
# * Esta podría ser una variable significativa para un modelo de regresión

# %% [markdown]
# ## Stakeholders

# %% [markdown]
# * Gobierno (SEMARNAT)
# * Empresas que busquen ser más amigables al medio ambiente
# * Organizaciones no lucrativas que busquen hacer un impacto positivo ambiental
# * United Nations (ODS)

# %% [markdown]
# ## Conclusión

# %% [markdown]
# * Utilización de Python para visualización de datos
# * Diferentes herramientas
# * Aplicación de lo visto en clase a una base de datos
# * Conocer sobre las emisiones de CO2 mundialmente; concientizarnos.
